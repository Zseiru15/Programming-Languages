# %% [markdown]
# # Impresion por pantalla
# <code>print(var1, var2, var3)<code/>

# %%
## Suma +
print('3+2 = ', 3+2)
# Out:
# 3+2 =  5

# %%
## Resta -
print('5-2 = ', 5-2)
# Out:
# 5-2 =  3

# %%
## Multiplicacion *
print('4*7 = ', 4*7)
# Out:
# 4*7 =  28

# %%
## Division /
print('8/2 = ', 8/2)
# Out:
# 8/2 =  4.0

# %%
## Division entera //
print('25//6 = ', 25//6)
# Out:
# 25//6 =  4

# %% [markdown]
# Escribir una expresion que calcuale cuantas horas hay en 160 minutos

# %%
160//60
# Out:
# 2

# %%
# Expresion amtematica
30+2*60
# Out:
# 150

# %% [markdown]
# Realizar un codigo que cualculo las raices de una ecuacion cuadratica del tipo ax^2 + bx + c

# %%
# Ecuacion x^2 + 5x + 6
# Forumula (-b +- Raiz b^2 -4ac) / 2a
a= 1
b=5
c=6

# %%
# b^2 - 4ac
h = b**2 - 4 * a * c
x1 = (-b + h**0.5)/(2*a)
x1
# Out:
# -2.0

# %%
# b^2 - 4ac
h = b**2 - 4 * a * c
x2 = (-b - h**0.5)/(2*a)
x2
# Out:
# -3.0

# %% [markdown]
# # Variables

# %%
X = 60
x = X/2
x
# Out:
# 30.0

# %%
total_min = 150
total_hor = 150//60
print("El numero total de horas es: ", total_hor)
# Out:
# El numero total de horas es:  2

# %% [markdown]
# 1. Escribe una espresion para sumar 30 y 20 y restar 40

# %%
a=30
b=20
c=40
x=a+b-c
x
# Out:
# 10

# %% [markdown]
# 2. Escribe una expresion para restar 5 de 55 y dividir el resultado entre 10

# %%
a = 5
b = 55
c = 10
x = (b - a) // c
x
# Out:
# 5

# %% [markdown]
# 3. Escribe una expresion para multiplicar 6 por 10 y dividir el resultado entre 12

# %%
a = 6
b = 10
c = 12
x = (a * 10) // c
x
# Out:
# 5

# %% [markdown]
# 4. ¿Cual es el valor de x donde <code>x = 3 + 2 * 2<code/>?

# %%
x = 3 + 2 * 2
x
# Out:
# 7

# %% [markdown]
# 5. ¿Cual es el valor de y donde y = (3 + 2) * 2?

# %%
y = (3 + 2) * 2
y
# Out:
# 10

# %% [markdown]
# 6. ¿Cual es el valor de z donde z = (3 + 2) * 2?

# %%
z = (3 + 2) * 2
z
# Out:
# 10

# %%
# Variable String 
# "" ''

# %%
texto = "El hombre guardian"

# %%
type(texto)
# Out:
# str

# %%
# Concatenacion 
texto1 = texto + ', estaba durmiendo'
texto1
# Out:
# 'El hombre guardian, estaba durmiendo'

# %%
# Multiplicacion
3 * texto
# Out:
# 'El hombre guardianEl hombre guardianEl hombre guardian'

# %%
print('indexaciones positivas')
print('texto[0] =', texto[0])
print('texto[1] =', texto[1])
print('texto[2] =', texto[2])
print('texto[3] =', texto[3])
print('texto[4] =', texto[4])
print('texto[5] =', texto[5])
print('texto[6] =', texto[6])
print('texto[7] =', texto[7])
print('texto[8] =', texto[8])
print('texto[9] =', texto[9])
print('texto[10] =', texto[10])
print('texto[11] =', texto[11])
print('texto[12] =', texto[12])
print('texto[13] =', texto[13])
print('texto[14] =', texto[14])
print('texto[15] =', texto[15])
print('texto[16] =', texto[16])
print('texto[17] =', texto[17])
print(' ')
print('indexaciones negativas')
print('texto[0] =', texto[0])
print('texto[-1] =', texto[-1])
print('texto[-2] =', texto[-2])
print('texto[-3] =', texto[-3])
print('texto[-4] =', texto[-4])
print('texto[-5] =', texto[-5])
print('texto[-6] =', texto[-6])
print('texto[-7] =', texto[-7])
print('texto[-8] =', texto[-8])
print('texto[-9] =', texto[-9])
print('texto[-10] =', texto[-10])
print('texto[-11] =', texto[-11])
print('texto[-12] =', texto[-12])
print('texto[-13] =', texto[-13])
print('texto[-14] =', texto[-14])
print('texto[-15] =', texto[-15])
print('texto[-16] =', texto[-16])
print('texto[-17] =', texto[-17])
# Out:
# indexaciones positivas
# texto[0] = E
# texto[1] = l
# texto[2] =
# texto[3] = h
# texto[4] = o
# texto[5] = m
# texto[6] = b
# texto[7] = r
# texto[8] = e
# texto[9] =
# texto[10] = g
# texto[11] = u
# texto[12] = a
# texto[13] = r
# texto[14] = d
# texto[15] = i
# texto[16] = a
# texto[17] = n
#
# indexaciones negativas
# texto[0] = E
# texto[-1] = n
# texto[-2] = a
# texto[-3] = i
# texto[-4] = d
# texto[-5] = r
# texto[-6] = a
# texto[-7] = u
# texto[-8] = g
# texto[-9] =
# texto[-10] = e
# texto[-11] = r
# texto[-12] = b
# texto[-13] = m
# texto[-14] = o
# texto[-15] = h
# texto[-16] =
# texto[-17] = l

# %% [markdown]
# # Slicing

# %%
# E l h o m b r e guardian
#     3 4 5 6 7 8 9
subtexto = texto[3:9]
subtexto
# Out:
# 'hombre'

# %%
subtexto = texto[3:10]
subtexto
# Out:
# 'hombre '

# %%
texto[2:]
# Out:
# ' hombre guardian'

# %%
len(texto)
# Out:
# 18

# %%
texto[:15]
# Out:
# 'El hombre guard'

# %%
## [Inicio:Final:Paso]
texto[2:15:2]
# Out:
# ' obegad'

# %%
texto[::2]
# Out:
# 'E obegada'

# %% [markdown]
# # Clases

# %%
texto = 'Ana Maria no vino a clase'
texto
# Out:
# 'Ana Maria no vino a clase'

# %%
# Clase .upper
texto1 = texto.upper()
texto1

# %%
# Clase .lower
texto2 = texto.lower()
texto2
# Out:
# 'ana maria no vino a clase'

# %%
# Clase .replace
texto2 = texto.replace('Ana Maria', 'Lina Sahory')
texto2
# Out:
# 'Lina Sahory no vino a clase'
