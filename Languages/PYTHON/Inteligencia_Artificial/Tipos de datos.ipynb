# %% [markdown]
# # Tipos de datos

# %%
# Entero
3
# Out:
# 3

# %%
# Float
2.14
# Out:
# 2.14

# %%
# String
"Hola python 1 "
# Out:
# 'Hola python 1 '

# %%
# Type Entero
type(3)
# Out:
# int

# %%
# Type Float
type(2.14)
# Out:
# float

# %%
#type String
type("Hola python")
# Out:
# str

# %% [markdown]
# # Realizar conversion de tipo de datos

# %%
type(int('1'))
# Out:
# int

# %%
type(float(5))
# Out:
# float

# %%
float('5.268')
# Out:
# 5.268

# %%
int('Hola python')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 int('Hola python')
#
# ValueError: invalid literal for int() with base 10: 'Hola python'

# %%
int(3.1416)
# Out:
# 3

# %%
int(3.56)
# Out:
# 3

# %% [markdown]
# # Tipo de dato Booleano

# %%
# True
bool(1)
# Out:
# True

# %%
# False
bool(0)
# Out:
# False

# %%
# Uno
bool(1)
# Out:
# True

# %% [markdown]
# 1. ¿Cual es el tipo de dato del restultado: 6/2?

# %%
type(6/2)
# Out:
# float

# %%
6/2
# Out:
# 3.0

# %% [markdown]
# 2. ¿Que tipo de resultado tiene la operacion: 6//2? (Observe la doble barra inclinada //)

# %%
type(6//2)
# Out:
# int

# %%
6//2
# Out:
# 3

# %% [markdown]
# 3. ¿Cual es el tipo de resultado de: "Hola, mundo!"?

# %%
type('Hola, mundo!')
# Out:
# str

# %%
'Hola, mundo!'
# Out:
# 'Hola, mundo!'

# %% [markdown]
# 4. ¿Cual es el tipo de resultado de: "hola" == "mundo"?

# %%
"hola" == "mundo"
# Out:
# False

# %% [markdown]
# 5. Escribe el codigo para convertir el siguiente numero que representa el ID de empleado "1001" a un numero entero.

# %%
type('1001')
# Out:
# str

# %%
type(int('1001'))
# Out:
# int

# %% [markdown]
# 6. Escribe el codigo para convertir este numero que representa el valor financiero "1234.56" a un numero de punto flotante.

# %%
type('1234.56')
# Out:
# str

# %%
type(float('1234.56'))
# Out:
# float

# %% [markdown]
# 7. Escribe el codigo para convertir este numero de telefono 123-456-7890 a una cadena de texto.

# %%
type(123-456-7890)
# Out:
# int

# %%
type(str(123-456-7890))
# Out:
# str
